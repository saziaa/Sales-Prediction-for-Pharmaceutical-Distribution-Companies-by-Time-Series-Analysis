# %%
import pandas as pd
import numpy as np
import warnings
import itertools
import matplotlib
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf


# Ignore the warning, can comment this 
warnings.filterwarnings("ignore")

# For graphing purpose, can change 
plt.style.use('seaborn-bright')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# # Upload Data and Indexing with Time

# %%
#load the dataset
df_daily = pd.read_csv("C:\\Users\\User\\Desktop\\Ryerson\\CIND 820\\Dataset\\salesdaily.csv")
df_daily.drop(['Year','Month','Hour','Weekday Name'], axis=1, inplace=True)
df_daily['datum'] = pd.to_datetime(df_daily['datum'])
df_daily.rename(columns = {'datum':'Date'}, inplace = True)

# Set the date as index 
df_daily = df_daily.set_index('Date')

# Select the proper time period for weekly aggreagation
df = df_daily['2014-01-02':'2019-10-8'].resample('W').sum()
df.head()
# Out:
#             M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# Date
# 2014-01-05  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 2014-01-12  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2014-01-19  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 2014-01-26  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 2014-02-02  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %% [markdown]
# # Visulization of the data

# %% [markdown]
# ##### To check the nature of the data

# %%
y = df['N02BE']
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Weekly')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.set_ylabel('Sales')
ax.legend();

# %% [markdown]
# ##### mean is not constant, variance is altering, and some seasonality is also visible

# %% [markdown]
# # Decomposing the Data

# %% [markdown]
# ##### To visualize trend, seasonality and residual of data

# %%
# graphs to show seasonal_decompose
def seasonal_decompose (y):
    decomposition = sm.tsa.seasonal_decompose(y, model='additive',extrapolate_trend='freq')
    fig = decomposition.plot()
    fig.set_size_inches(14,7)
    plt.show()

# %%
seasonal_decompose(y)

# %% [markdown]
# # Partial autocorrelation & Autocorrelation

# %% [markdown]
# #####  the wavy correlations for the seasonal pattern and the slowly diminishing lags of a trend is visible in ACF

# %%
pacf_plot = plot_pacf(df['N02BE'] , lags=30)

# %%
acf_plot = plot_acf(df['N02BE'] , lags=30)

# %% [markdown]
# # Checking Stationarity

# %% [markdown]
# ### Visualization: Graphing the rolling statistics

# %%
### plot for Rolling Statistic for testing Stationarity
def test_stationarity(timeseries, title):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean() 
    rolstd = pd.Series(timeseries).rolling(window=12).std()
    
    fig, ax = plt.subplots(figsize=(16, 4))
    ax.plot(timeseries, label= title)
    ax.plot(rolmean, label='rolling mean');
    ax.plot(rolstd, label='rolling std (x10)');
    ax.legend()

# %%
pd.options.display.float_format = '{:.8f}'.format
test_stationarity(y,'raw data')

# %% [markdown]
# ##### both the mean and the standard deviation are changing over time

# %% [markdown]
# ### Augmented Dickey-Fuller Test

# %%
# Augmented Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller , kpss

def ADF_test(timeseries, dataDesc):
    print(' > Is the {} stationary ?'.format(dataDesc))
    dftest = adfuller(timeseries.dropna(), autolag='AIC')
    print('Test statistic = {:.3f}'.format(dftest[0]))
    print('P-value = {:.3f}'.format(dftest[1]))
    print('Critical values :')
    for k, v in dftest[4].items():
        print('\t{}: {} - The data is {} stationary with {}% confidence'.format(k, v, 'not' if v<dftest[0] else '', 100-int(k[:-1])))

# %%
ADF_test(y,'raw data')
# Out:
#  > Is the raw data stationary ?
# Test statistic = -4.371
# P-value = 0.000
# Critical values :
# 	1%: -3.4523371197407404 - The data is  stationary with 99% confidence
# 	5%: -2.871222860740741 - The data is  stationary with 95% confidence
# 	10%: -2.571929211111111 - The data is  stationary with 90% confidence

# %% [markdown]
# ### KPSS

# %%
def kpss_test(series, **kw):    
    statistic, p_value, n_lags, critical_values = kpss(series, **kw)
    # Format Output
    print(f'KPSS Statistic: {statistic}')
    print(f'p-value: {p_value}')
    print(f'num lags: {n_lags}')
    print('Critial Values:')
    for key, value in critical_values.items():
        print(f'   {key} : {value}')
    print(f'Result: The series is {"not " if p_value < 0.05 else ""}stationary')

kpss_test(df["N02BE"], regression="ct", nlags="auto")
# Out:
# KPSS Statistic: 0.10019806534660362
# p-value: 0.1
# num lags: 10
# Critial Values:
#    10% : 0.119
#    5% : 0.146
#    2.5% : 0.176
#    1% : 0.216
# Result: The series is stationary

# %% [markdown]
# # Detrending

# %% [markdown]
# ##### removes underlying trend of the time series

# %%
# Detrending
y_detrend =  (y - y.rolling(window=12).mean())/y.rolling(window=12).std()

test_stationarity(y_detrend,'de-trended data')
ADF_test(y_detrend,'de-trended data')
# Out:
#  > Is the de-trended data stationary ?
# Test statistic = -5.836
# P-value = 0.000
# Critical values :
# 	1%: -3.4531816058796143 - The data is  stationary with 99% confidence
# 	5%: -2.871593390724642 - The data is  stationary with 95% confidence
# 	10%: -2.5721268156511536 - The data is  stationary with 90% confidence

# %% [markdown]
# # Differencing

# %% [markdown]
# ##### removes underlying seasonal or cyclical pattern of the time series

# %%
# Differencing
first_diff = df['M01AB'].diff()
test_stationarity(first_diff,'differenced data')
ADF_test(first_diff,'differenced data')
# Out:
#  > Is the differenced data stationary ?
# Test statistic = -7.111
# P-value = 0.000
# Critical values :
# 	1%: -3.4535050041524245 - The data is  stationary with 99% confidence
# 	5%: -2.8717352599720294 - The data is  stationary with 95% confidence
# 	10%: -2.5722024776854417 - The data is  stationary with 90% confidence

# %% [markdown]
# # Set the y_to_train, y_to_test, and the length of predict units

# %%
y_to_train = y[:'2018-01-14'] # dataset to train
y_to_val = y['2018-01-21':] # last X months for test  
predict_date = len(y) - len(y[:'2018-01-21']) # the number of data points for the test set

# %% [markdown]
# # Different Time Series Prediction Models

# %% [markdown]
# ### 1.SARIMA

# %% [markdown]
# ### Plotting PACF & ACF of first differencing

# %% [markdown]
# ##### To identify initial p, seasonal P (from PACF) & q, seassonal q (from ACF)

# %%
pacf_plot = plot_pacf(df['N02BE'].diff()[1:])

# %%
acf_plot = plot_acf(df['N02BE'].diff()[1:])

# %% [markdown]
# ### Grid search for the combination of (p.d,q) & (P,D,Q)m

# %%
import itertools

def sarima_grid_search(y,seasonal_period):
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2],seasonal_period) for x in list(itertools.product(p, d, q))]
    
    mini = float('+inf')
    
    
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(y,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)

                results = mod.fit()
                
                if results.aic < mini:
                    mini = results.aic
                    param_mini = param
                    param_seasonal_mini = param_seasonal

#                 print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue
    print('The set of parameters with the minimum AIC is: SARIMA{}x{} - AIC:{}'.format(param_mini, param_seasonal_mini, mini))

# %%
sarima_grid_search(y,12)
# Out:
# The set of parameters with the minimum AIC is: SARIMA(1, 0, 1)x(0, 1, 1, 12) - AIC:2915.983948692457

# %% [markdown]
# ### Model fitting, forecasting & evaluation

# %%
# Call this function after pick the right(p,d,q) for SARIMA based on AIC               
def sarima_eva(y,order,seasonal_order,seasonal_period,pred_date,y_to_test):
    # fit the model 
    mod = sm.tsa.statespace.SARIMAX(y,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)

    results = mod.fit()
    print(results.summary().tables[1])
    
    results.plot_diagnostics(figsize=(16, 8))
    plt.show()
    
    # The dynamic=False argument ensures that we produce one-step ahead forecasts, 
    # meaning that forecasts at each point are generated using the full history up to that point.
    pred = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=False)
    pred_ci = pred.conf_int()
    y_forecasted = pred.predicted_mean
    mse = ((y_forecasted - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = False {}'.format(seasonal_period,round(np.sqrt(mse), 2)))

    ax = y.plot(label='observed')
    y_forecasted.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('Date')
    ax.set_ylabel('Sessions')
    plt.legend()
    plt.show()
    # A better representation of our true predictive power can be obtained using dynamic forecasts. 
    # In this case, we only use information from the time series up to a certain point, 
    # and after that, forecasts are generated using values from previous forecasted time points.
    pred_dynamic = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=True, full_results=True)
    pred_dynamic_ci = pred_dynamic.conf_int()
    y_forecasted_dynamic = pred_dynamic.predicted_mean
    mse_dynamic = ((y_forecasted_dynamic - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = True {}'.format(seasonal_period,round(np.sqrt(mse_dynamic), 2)))

    ax = y.plot(label='observed')
    y_forecasted_dynamic.plot(label='Dynamic Forecast', ax=ax,figsize=(14, 7))
    ax.fill_between(pred_dynamic_ci.index,
                    pred_dynamic_ci.iloc[:, 0],
                    pred_dynamic_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('Date')
    ax.set_ylabel('Sessions')

    plt.legend()
    plt.show()
    
    return (results)

# %%
model = sarima_eva(y,(1, 0, 1),(0, 1, 1, 12),12,'2018-01-21',y_to_val)
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8851      0.034     25.814      0.000       0.818       0.952
# ma.L1         -0.2048      0.063     -3.270      0.001      -0.328      -0.082
# ma.S.L12      -1.0000      0.053    -19.011      0.000      -1.103      -0.897
# sigma2      1975.3702   2.66e-05   7.42e+07      0.000    1975.370    1975.370
# ==============================================================================
# The Root Mean Squared Error of SARIMA with season_length=12 and dynamic = False 46.24
# The Root Mean Squared Error of SARIMA with season_length=12 and dynamic = True 74.56

# %% [markdown]
# # Making Predictions

# %%
def forecast(model,predict_steps,y): #predict_steps = 12 weeks(3 months)
    
    pred_uc = model.get_forecast(steps=predict_steps)

    pred_ci = pred_uc.conf_int()

    ax = y.plot(label='observed', figsize=(14, 7))
    
    #print(pred_uc.predicted_mean)
    pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.05)
    ax.set_xlabel('Date')
    ax.set_ylabel(y.name)

    plt.legend()
    plt.show()
    
    # Produce the forcasted tables 
    pm = pred_uc.predicted_mean.reset_index()
    pm.columns = ['Date','Predicted_Mean']
    pci = pred_ci.reset_index()
    pci.columns = ['Date','Lower Bound','Upper Bound']
    final_table = pm.join(pci.set_index('Date'), on='Date')
    
    return (final_table)

# %%
final_table = forecast(model,12,y)
final_table.head()
# Out:
#         Date  Predicted_Mean  Lower Bound  Upper Bound
# 0 2019-10-20    136.84062626  48.00136199 225.67989052
# 1 2019-10-27    142.31639037  34.87071246 249.76206828
# 2 2019-11-03    157.19808526  37.17429155 277.22187897
# 3 2019-11-10    151.45059895  22.42674625 280.47445164
# 4 2019-11-17    145.15653630   9.49842265 280.81464996

# %%
### Graphs without the confident interval 
pred_uc = model.get_forecast(steps=51)
ax = y.plot(label='observed', figsize=(14, 7))
#print(pred_uc.predicted_mean)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel(y.name)

plt.legend()
plt.show()

# %%
### Graphs show only the perdiected period
final_table.index = final_table.Date
fig, ax = plt.subplots( figsize=(14, 7))
# ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Weekly')
ax.plot(final_table.Predicted_Mean,marker='.', linestyle='-', linewidth=0.5, label='Predicted Weekly')
# ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.plot(final_table.Predicted_Mean.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Predicted Monthly Mean Resample')
ax.set_ylabel('Orders')
ax.legend();

# %% [markdown]
# # 2.Prophet Model

# %%
import warnings; 
warnings.simplefilter('ignore')
import pandas as pd
import prophet
from prophet.plot import plot_plotly,plot_components_plotly
from prophet import Prophet
from statsmodels.tools.eval_measures import rmse

# %% [markdown]
# # Load & preprocess data

# %%
#load the dataset
df_daily = pd.read_csv("C:\\Users\\User\\Desktop\\Ryerson\\CIND 820\\Dataset\\salesdaily.csv")
df_daily.drop(['Year','Month','Hour','Weekday Name','M01AB', 'M01AE', 'N02BA', 'N05B', 'N05C', 'R03','R06'], axis=1, inplace=True)
df_daily['datum'] = pd.to_datetime(df_daily['datum'])
df_daily.rename(columns = {'datum':'Date'}, inplace = True)

df_daily.head()
# Out:
#         Date       N02BE
# 0 2014-01-02 32.40000000
# 1 2014-01-03 50.60000000
# 2 2014-01-04 61.85000000
# 3 2014-01-05 41.10000000
# 4 2014-01-06 21.70000000

# %%
df_daily.columns = ['ds', 'y']
df_daily.head()
# Out:
#           ds           y
# 0 2014-01-02 32.40000000
# 1 2014-01-03 50.60000000
# 2 2014-01-04 61.85000000
# 3 2014-01-05 41.10000000
# 4 2014-01-06 21.70000000

# %% [markdown]
# # Create the model

# %% [markdown]
# ### a.Train,Test Split

# %%
train = df_daily.iloc[:len(df_daily)-631]
test = df_daily.iloc[len(df_daily)-631:]

# %% [markdown]
# ### b.Fitting the model & making predictions

# %% [markdown]
# ##### yearly seasonality is present so yearly_seasonality=True and from test to prediction there are 25 months so periods=25

# %%
m = Prophet(interval_width=0.95, yearly_seasonality=True)
m.fit(train)
future = m.make_future_dataframe(periods=25,freq='M')
forecast = m.predict(future)
forecast.tail()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#              ds      trend   yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 1495 2019-09-30 7.46391691  -5.75373452 43.78557853  -0.10980390  15.60833233
# 1496 2019-10-31 6.73977614 -14.63720219 37.62925903  -1.37237496  15.37383442
# 1497 2019-11-30 6.03899474 -15.18778289 36.48115836  -2.67140856  15.09224529
# 1498 2019-12-31 5.31485397  -4.37367073 45.63194213  -4.08296993  14.97671582
# 1499 2020-01-31 4.59071319 -21.29919946 33.28729462  -5.32029526  14.61160023
#
#       additive_terms  additive_terms_lower  additive_terms_upper      weekly  \
# 1495     10.74827916           10.74827916           10.74827916 -0.67298605
# 1496      5.84139726            5.84139726            5.84139726 -1.63701481
# 1497      5.76754362            5.76754362            5.76754362  3.70136339
# 1498     16.24387279           16.24387279           16.24387279 -0.76486416
# 1499      2.00698279            2.00698279            2.00698279 -1.85040825
#
#       weekly_lower  weekly_upper      yearly  yearly_lower  yearly_upper  \
# 1495   -0.67298605   -0.67298605 11.42126521   11.42126521   11.42126521
# 1496   -1.63701481   -1.63701481  7.47841208    7.47841208    7.47841208
# 1497    3.70136339    3.70136339  2.06618022    2.06618022    2.06618022
# 1498   -0.76486416   -0.76486416 17.00873695   17.00873695   17.00873695
# 1499   -1.85040825   -1.85040825  3.85739104    3.85739104    3.85739104
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 1495            0.00000000                  0.00000000
# 1496            0.00000000                  0.00000000
# 1497            0.00000000                  0.00000000
# 1498            0.00000000                  0.00000000
# 1499            0.00000000                  0.00000000
#
#       multiplicative_terms_upper        yhat
# 1495                  0.00000000 18.21219608
# 1496                  0.00000000 12.58117340
# 1497                  0.00000000 11.80653836
# 1498                  0.00000000 21.55872676
# 1499                  0.00000000  6.59769599

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#              ds        yhat   yhat_lower  yhat_upper
# 1495 2019-09-30 18.21219608  -5.75373452 43.78557853
# 1496 2019-10-31 12.58117340 -14.63720219 37.62925903
# 1497 2019-11-30 11.80653836 -15.18778289 36.48115836
# 1498 2019-12-31 21.55872676  -4.37367073 45.63194213
# 1499 2020-01-31  6.59769599 -21.29919946 33.28729462

# %% [markdown]
# ### c.Visualizing the forecast

# %%
plot_plotly(m,forecast)
# Out:
# <div>                            <div id="1422699b-ab13-47a7-8f16-a6aef2662a16" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1422699b-ab13-47a7-8f16-a6aef2662a16")) {                    Plotly.newPlot(                        "1422699b-ab13-47a7-8f16-a6aef2662a16",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2014-01-02T00:00:00","2014-01-03T00:00:00","2014-01-04T00:00:00","2014-01-05T00:00:00","2014-01-06T00:00:00","2014-01-07T00:00:00","2014-01-08T00:00:00","2014-01-09T00:00:00","2014-01-10T00:00:00","2014-01-11T00:00:00","2014-01-12T00:00:00","2014-01-13T00:00:00","2014-01-14T00:00:00","2014-01-15T00:00:00","2014-01-16T00:00:00","2014-01-17T00:00:00","2014-01-18T00:00:00","2014-01-19T00:00:00","2014-01-20T00:00:00","2014-01-21T00:00:00","2014-01-22T00:00:00","2014-01-23T00:00:00","2014-01-24T00:00:00","2014-01-25T00:00:00","2014-01-26T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-01T00:00:00","2014-02-02T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-08T00:00:00","2014-02-09T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-15T00:00:00","2014-02-16T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-22T00:00:00","2014-02-23T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-27T00:00:00","2014-02-28T00:00:00","2014-03-01T00:00:00","2014-03-02T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-08T00:00:00","2014-03-09T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-15T00:00:00","2014-03-16T00:00:00","2014-03-17T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-23T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-29T00:00:00","2014-03-30T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-05T00:00:00","2014-04-06T00:00:00","2014-04-07T00:00:00","2014-04-08T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-12T00:00:00","2014-04-13T00:00:00","2014-04-14T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-18T00:00:00","2014-04-19T00:00:00","2014-04-20T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-24T00:00:00","2014-04-25T00:00:00","2014-04-26T00:00:00","2014-04-27T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-01T00:00:00","2014-05-02T00:00:00","2014-05-03T00:00:00","2014-05-04T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-10T00:00:00","2014-05-11T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-17T00:00:00","2014-05-18T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-24T00:00:00","2014-05-25T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-05-31T00:00:00","2014-06-01T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014 ...

# %% [markdown]
# ##### in the plot,forecasted data did not fit that well to the actual data and some outliers are also present.

# %% [markdown]
# ### d.Visualizing the trend

# %%
plot_components_plotly(m,forecast)
# Out:
# <div>                            <div id="c04d6929-fa6a-4883-baae-22b37e64932d" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c04d6929-fa6a-4883-baae-22b37e64932d")) {                    Plotly.newPlot(                        "c04d6929-fa6a-4883-baae-22b37e64932d",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2014-01-02T00:00:00","2014-01-03T00:00:00","2014-01-04T00:00:00","2014-01-05T00:00:00","2014-01-06T00:00:00","2014-01-07T00:00:00","2014-01-08T00:00:00","2014-01-09T00:00:00","2014-01-10T00:00:00","2014-01-11T00:00:00","2014-01-12T00:00:00","2014-01-13T00:00:00","2014-01-14T00:00:00","2014-01-15T00:00:00","2014-01-16T00:00:00","2014-01-17T00:00:00","2014-01-18T00:00:00","2014-01-19T00:00:00","2014-01-20T00:00:00","2014-01-21T00:00:00","2014-01-22T00:00:00","2014-01-23T00:00:00","2014-01-24T00:00:00","2014-01-25T00:00:00","2014-01-26T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-01T00:00:00","2014-02-02T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-08T00:00:00","2014-02-09T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-15T00:00:00","2014-02-16T00:00:00","2014-02-17T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-22T00:00:00","2014-02-23T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-27T00:00:00","2014-02-28T00:00:00","2014-03-01T00:00:00","2014-03-02T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-08T00:00:00","2014-03-09T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-15T00:00:00","2014-03-16T00:00:00","2014-03-17T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-22T00:00:00","2014-03-23T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-29T00:00:00","2014-03-30T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-05T00:00:00","2014-04-06T00:00:00","2014-04-07T00:00:00","2014-04-08T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-12T00:00:00","2014-04-13T00:00:00","2014-04-14T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-18T00:00:00","2014-04-19T00:00:00","2014-04-20T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-24T00:00:00","2014-04-25T00:00:00","2014-04-26T00:00:00","2014-04-27T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-01T00:00:00","2014-05-02T00:00:00","2014-05-03T00:00:00","2014-05-04T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-10T00:00:00","2014-05-11T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-17T00:00:00","2014-05-18T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-24T00:00:00","2014-05-25T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-05-31T00:00:00","2014-06-01T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-0 ...

# %% [markdown]
# ##### the trend is decreasing and yearly and weekly seasonality is clearly visible

# %% [markdown]
# # Evaluate the model

# %%
predictions = forecast.iloc[-631:]['yhat']
print("Root Mean Squared Error between actual and  predicted values: ",rmse(predictions,test['y']))
# Out:
# Root Mean Squared Error between actual and  predicted values:  20.07696998638815

# %% [markdown]
# # 3.SVR model

# %%
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math
import plotly.graph_objects as go 
import plotly.express as px


from sklearn.svm import SVR

from sklearn.preprocessing import MinMaxScaler
from IPython.display import Image

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
np.set_printoptions(precision=2)
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %% [markdown]
# ### Load the dataset

# %%
#load the dataset
df_daily = pd.read_csv("C:\\Users\\User\\Desktop\\Ryerson\\CIND 820\\Dataset\\salesdaily.csv")
df_daily.drop(['Year','Month','Hour','Weekday Name'], axis=1, inplace=True)

df_daily['datum'] = pd.to_datetime(df_daily['datum'])
df_daily.rename(columns = {'datum':'Date'}, inplace = True)
# Set the date as index 
df_daily = df_daily.set_index('Date')
df_daily.head()
# Out:
#             M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06
# Date
# 2014-01-02   0.00   3.67   3.40  32.40  7.00  0.00  0.00 2.00
# 2014-01-03   8.00   4.00   4.40  50.60 16.00  0.00 20.00 4.00
# 2014-01-04   2.00   1.00   6.50  61.85 10.00  0.00  9.00 1.00
# 2014-01-05   4.00   3.00   7.00  41.10  8.00  0.00  3.00 0.00
# 2014-01-06   5.00   1.00   4.50  21.70 16.00  2.00  6.00 2.00

# %% [markdown]
# ### Plotting the data

# %%
df_daily.plot(y='N02BE', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('sales volume of N02BE', fontsize=12)
plt.show()

# %% [markdown]
# ### Create training and testing datasets

# %%
train_start_dt = '2014-01-02'
test_start_dt = '2018-01-16'

# %% [markdown]
# ### Visualize the differences

# %%
df_daily[(df_daily.index < test_start_dt) & (df_daily.index >= train_start_dt)][['N02BE']].rename(columns={'N02BE':'train'}) \
    .join(df_daily[test_start_dt:][['N02BE']].rename(columns={'N02BE':'test'}), how='outer') \
    .plot(y=['train', 'test'], figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('N02BE', fontsize=12)
plt.show()

# %% [markdown]
# ### Prepare the data for training

# %%
train = df_daily.copy()[(df_daily.index >= train_start_dt) & (df_daily.index < test_start_dt)][['N02BE']]
test = df_daily.copy()[df_daily.index >= test_start_dt][['N02BE']]

print('Training data shape: ', train.shape)
print('Test data shape: ', test.shape)
# Out:
# Training data shape:  (1475, 1)
# Test data shape:  (631, 1)

# %%
# Scale the data to be in the range (0, 1)
scaler = MinMaxScaler()
train['N02BE'] = scaler.fit_transform(train)
train.head()
# Out:
#             N02BE
# Date
# 2014-01-02   0.20
# 2014-01-03   0.31
# 2014-01-04   0.38
# 2014-01-05   0.26
# 2014-01-06   0.13

# %%
test['N02BE'] = scaler.fit_transform(test)
test.head(5)
# Out:
#             N02BE
# Date
# 2018-01-16   0.18
# 2018-01-17   0.30
# 2018-01-18   0.58
# 2018-01-19   0.23
# 2018-01-20   0.38

# %% [markdown]
# ### Create data with time-steps

# %%
# Converting to numpy arrays
train_data = train.values
test_data = test.values
timesteps=5

# %%
#Converting training data to 2D tensor 
train_data_timesteps=np.array([[j for j in train_data[i:i+timesteps]] for i in range(0,len(train_data)-timesteps+1)])[:,:,0]
train_data_timesteps.shape
# Out:
# (1471, 5)

# %%
#Converting testing data to 2D tensor
test_data_timesteps=np.array([[j for j in test_data[i:i+timesteps]] for i in range(0,len(test_data)-timesteps+1)])[:,:,0]
test_data_timesteps.shape
# Out:
# (627, 5)

# %%
#Selecting inputs and outputs from training and testing data
x_train, y_train = train_data_timesteps[:,:timesteps-1],train_data_timesteps[:,[timesteps-1]]
x_test, y_test = test_data_timesteps[:,:timesteps-1],test_data_timesteps[:,[timesteps-1]]

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1471, 4) (1471, 1)
# (627, 4) (627, 1)

# %% [markdown]
# ### Hyperparameter tunning

# %%
model = SVR()

# %%
param_grid = {'kernel':['rbf'],'gamma': [0.1,0.01,0.001] , 'C':[0.1,1,10],'epsilon':[0.05,0.1]}

# %%
grid = GridSearchCV(SVR(),param_grid,refit = True, verbose = 3)

# %%
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END C=0.1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.144 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.032 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=-0.062 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.273 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.231 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.001 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.038 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=-0.311 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.059 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.005 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=-0.135 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.005 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=-0.498 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=-0.093 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=-0.152 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.057 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.004 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.024 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.257 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.027 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.264 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.002 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.209 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.046 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.244 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.322 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.019 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.308 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.034 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.347 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.156 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.008 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=-0.024 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.321 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.268 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.145 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.032 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=-0.063 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.273 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.231 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.001 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.038 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=-0.311 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.059 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.005 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.014 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.035 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.026 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.323 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.140 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.003 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.021 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.258 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.031 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.264 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.002 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.209 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=0.046 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.244 total time=   0.0s
# [CV 1/5] END C=10, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.159 total time=   0.0s
# [CV 2/5] END C=10, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.015 total time=   0.0s
# [CV 3/5] END C=10, epsilon=0.05, gamma=0.1, kernel=rbf;, score=-0.015 total time=   0.0s
# [CV 4/5] END C=10, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.319 total time=   0.0s
# [CV 5/5] END C=10, epsilon=0.05, gamma=0.1, kernel=rbf;, score=0.267 total time=   0.0s
# [CV 1/5] END C=10, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.155 total time=   0.0s
# [CV 2/5] END C=10, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.008 total time=   0.0s
# [CV 3/5] END C=10, epsilon=0.05, gamma=0.01, kernel=rbf;, score=-0.026 total time=   0.0s
# [CV 4/5] END C=10, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.319 total time=   0.0s
# [CV 5/5] END C=10, epsilon=0.05, gamma=0.01, kernel=rbf;, score=0.267 total time=   0.0s
# [CV 1/5] END C=10, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.145 total time=   0.0s
# [CV 2/5] END C=10, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.032 total time=   0.0s
# [CV 3/5] END C=10, epsilon=0.05, gamma=0.001, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 4/5] END C=10, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.273 total time=   0.0s
# [CV 5/5] END C=10, epsilon=0.05, gamma=0.001, kernel=rbf;, score=0.231 total time=   0.0s
# [CV 1/5] END C=10, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.039 total time=   0.0s
# [CV 2/5] END C=10, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.044 total time=   0.0s
# [CV 3/5] END C=10, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.021 total time=   0.0s
# [CV 4/5] END C=10, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.325 total time=   0.0s
# [CV 5/5] END C=10, epsilon=0.1, gamma=0.1, kernel=rbf;, score=0.180 total time=   0.0s
# [CV 1/5] END C=10, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.003 total time=   0.0s
# [CV 2/5] END C=10, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.034 total time=   0.0s
# [CV 3/5] END C=10, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.026 total time=   0.0s
# [CV 4/5] END C=10, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.320 total time=   0.0s
# [CV 5/5] END C=10, epsilon=0.1, gamma=0.01, kernel=rbf;, score=0.129 total time=   0.0s
# [CV 1/5] END C=10, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 2/5] END C=10, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.003 total time=   0.0s
# [CV 3/5] END C=10, epsilon=0.1, gamma=0.001, kernel=rbf;, score=-0.022 total time=   0.0s
# [CV 4/5] END C=10, epsilon=0.1, gamma=0.001, kernel=rbf;, score=0.258 total time=   0.0s
# [CV 5/5] END C=10, epsilon=0.1, gamma=0.001, kernel=rbf;, score=0.031 total time=   0.0s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'epsilon': [0.05, 0.1],
#                          'gamma': [0.1, 0.01, 0.001], 'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 10, 'epsilon': 0.05, 'gamma': 0.1, 'kernel': 'rbf'}

# %% [markdown]
# ### Fit the model on training data

# %%
model = SVR(kernel='rbf',gamma=0.1, C=10, epsilon = 0.05)
model.fit(x_train, y_train[:,0])
# Out:
# SVR(C=10, epsilon=0.05, gamma=0.1)

# %% [markdown]
# ### Making predictions

# %%
y_train_pred = model.predict(x_train).reshape(-1,1)
y_test_pred = model.predict(x_test).reshape(-1,1)

print(y_train_pred.shape, y_test_pred.shape)
# Out:
# (1471, 1) (627, 1)

# %% [markdown]
# ### Evaluate the model

# %%
# Scaling the predictions
y_train_pred = scaler.inverse_transform(y_train_pred)
y_test_pred = scaler.inverse_transform(y_test_pred)

print(len(y_train_pred), len(y_test_pred))
# Out:
# 1471 627

# %%
# Scaling the original values
y_train = scaler.inverse_transform(y_train)
y_test = scaler.inverse_transform(y_test)

print(len(y_train), len(y_test))
# Out:
# 1471 627

# %%
#Check model performance on training and testing data
train_timestamps = df_daily[(df_daily.index < test_start_dt) & (df_daily.index >= train_start_dt)].index[timesteps-1:]
test_timestamps = df_daily[test_start_dt:].index[timesteps-1:]

print(len(train_timestamps), len(test_timestamps))
# Out:
# 1471 627

# %%
# Plot the predictions for training data
plt.figure(figsize=(25,6))
plt.plot(train_timestamps, y_train, color = 'red', linewidth=2.0, alpha = 0.6)
plt.plot(train_timestamps, y_train_pred, color = 'blue', linewidth=0.8)
plt.legend(['Actual','Predicted'])
plt.xlabel('Timestamp')
plt.title("Training data prediction")
plt.show()

# %%
#Print RMSE for training data

rmse = np.sqrt(mse)
print(f'Root mean squared error: {rmse:.2f}')
# Out:
# Root mean squared error: 12.83

# %%
#plot the predictions for testing data
plt.figure(figsize=(25,6))
plt.plot(test_timestamps, y_test, color = 'red', linewidth=2.0, alpha = 0.6)
plt.plot(test_timestamps, y_test_pred, color = 'blue', linewidth=0.8)
plt.legend(['Actual','Predicted'])
plt.xlabel('Timestamp')
plt.show()

# %%
#Print RMSE for testing data

rmse = np.sqrt(mse)
print(f'Root mean squared error: {rmse:.2f}')
# Out:
# Root mean squared error: 12.83

# %%
##Check model performance on full dataset 

# Extracting N02BE sales values as numpy array
data = df_daily.copy().values
data = data.reshape(-1, 1)

# Scaling
data = scaler.transform(data)

# Transforming to 2D tensor as per model input requirement
data_timesteps=np.array([[j for j in data[i:i+timesteps]] for i in range(0,len(data)-timesteps+1)])[:,:,0]
print("Tensor shape: ", data_timesteps.shape)

# Selecting inputs and outputs from data
X, Y = data_timesteps[:,:timesteps-1],data_timesteps[:,[timesteps-1]]
print("X shape: ", X.shape,"\nY shape: ", Y.shape)
# Out:
# Tensor shape:  (16844, 5)
# X shape:  (16844, 4)
# Y shape:  (16844, 1)

# %%
# Make model predictions
Y_pred = model.predict(X).reshape(-1,1)

# Inverse scale and reshape
Y_pred = scaler.inverse_transform(Y_pred)
Y = scaler.inverse_transform(Y)

# %%
plt.figure(figsize=(30,8))
plt.plot(Y, color = 'red', linewidth=2.0, alpha = 0.6)
plt.plot(Y_pred, color = 'blue', linewidth=0.8)
plt.legend(['Actual','Predicted'])
plt.xlabel('Timestamp')
plt.show()

# %%
##Print RMSE for full dataset

rmse = np.sqrt(mse)
print(f'Root mean squared error: {rmse:.2f}')
# Out:
# Root mean squared error: 12.83
